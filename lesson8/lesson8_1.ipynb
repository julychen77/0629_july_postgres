# %%
sql = """SELECT  "stationCode","name",日期,進站人數,出站人數,"stationAddrTw"
FROM "台鐵車站資訊" LEFT JOIN "每日各站進出站人數" ON "stationCode" = "車站代碼"
WHERE "stationAddrTw" LIKE '%臺北%' ;"""

print(sql)
# Out:
# SELECT  "stationCode","name",日期,進站人數,出站人數,"stationAddrTw"
# FROM "台鐵車站資訊" LEFT JOIN "每日各站進出站人數" ON "stationCode" = "車站代碼"
# WHERE "stationAddrTw" LIKE '%臺北%' ;

# %%
# 使用subscript取出tuple的值，tuple以()表現，tuple建立後無法再修改。
student = (65,70,30,20) #sequence串列資料
student[0]
#tuple通常用於查詢暫存，查詢後拆解出來給變數用
m,n = 70, 30
print(m,n)
# Out:
# 70 30

# %%
# 使用subscript取出list值，list以[]表現，list建立後可以增刪修。
student2 = [65,70,30,20] #sequence串列資料
student2[1]
# Out:
# 70

# %%
#建立dict(dictionary)
student3 = {'chinese':67,'english':75,'nature':80,'math':95} #mapping 映射資料
# 使用subscript以鍵值查詢取出dict值，dict以{}表現，dict建立後可以增刪修。
student3['math']
# Out:
# 95

# %%
#建立4個學生的list
student1 = [87, 76, 65, 78, 92] #Sequence(序列資料)
student2 = [67, 75, 89, 87, 92] #Sequence(序列資料)
student3 = [78, 82, 90, 85, 88] #Sequence(序列資料)
student4 = [80, 70, 75, 90, 95] #Sequence(序列資料)

#建立4個學生的dict
student5 = {'chinese':87,'english':76,'math':65,'history':78,'discovery':92} #mapping(映射資料)
student6 = {'chinese':67,'english':75,'math':89,'history':87,'discovery':92}
student7 = {'chinese':78,'english':82,'math':90,'history':85,'discovery':88}
student8 = {'chinese':80,'english':70,'math':75,'history':90,'discovery':95}

#建立students的list,包含4個學生的dict
students = [student5, student6, student7, student8] #Sequence(序列資料)
students

students[0]['chinese']
students[2]['chinese']
# Out:
# 78

# %%
my_list = [1,2,3,4,5]
for i in my_list:
    print(i*3)
print("=========")
for word in "Apple": #字串也是一種串列資料
    print(word)
# Out:
# 3
# 6
# 9
# 12
# 15
# =========
# A
# p
# p
# l
# e
