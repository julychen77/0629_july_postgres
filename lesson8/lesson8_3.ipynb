# %%
#定義一個函式
def sayHello():
    print("Hello,world!")
#呼叫函式
sayHello()
# Out:
# Hello,world!

# %%
#定義一個函式，有一個參數
def say_hello(name):
    print(name,"你好!")

#把引數值Robert帶入參數，並呼叫函式
say_hello("Robert")
# Out:
# Robert 你好!
